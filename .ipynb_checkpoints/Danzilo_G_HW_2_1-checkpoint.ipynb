# %%
# Import Packages 
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Data Merge

# %%
data_2014 = pd.read_csv("../data/output/data-2014.csv")
data_2015 = pd.read_csv("../data/output/data-2015.csv")
data_2016 = pd.read_csv("../data/output/data-2016.csv")
data_2017 = pd.read_csv("../data/output/data-2017.csv")
data_2018 = pd.read_csv("../data/output/data-2018.csv")
data_2019 = pd.read_csv("../data/output/data-2019.csv")

# %%
data_2014.head()
# Out:
#   contractid  planid     fips  year  n_nonmiss  avg_enrollment  sd_enrollment  \
# 0      H0028     1.0  19103.0  2014          2           238.0       2.828427
# 1      H0028     1.0  19113.0  2014          2          1334.5       4.949747
# 2      H0028     2.0  19153.0  2014          2           347.0       1.414214
# 3      H0028     3.0  19155.0  2014          2           173.0      11.313708
# 4      H0028     4.0  15003.0  2014          2          1019.5      20.506097
#
#    min_enrollment  max_enrollment  first_enrollment  ...  costsharing_partd  \
# 0           236.0           240.0             240.0  ...                NaN
# 1          1331.0          1338.0            1338.0  ...                NaN
# 2           346.0           348.0             346.0  ...              37.09
# 3           165.0           181.0             165.0  ...              37.96
# 4          1005.0          1034.0            1034.0  ...              14.16
#
#   riskscore_partd parta_enroll  parta_reimb partb_enroll  partb_reimb  \
# 0             NaN      11616.0   32301567.0       9903.0   34882291.0
# 1             NaN      22144.0   67258119.0      20138.0   79300733.0
# 2           0.910      46091.0  138761798.0      41137.0  146914297.0
# 3           0.983      10934.0   38584530.0      10013.0   40401051.0
# 4           0.829      76625.0  198161786.0      59102.0  182990122.0
#
#   mean_risk year_ffs basic_premium         bid
# 0     0.904   2014.0           1.0         NaN
# 1     0.956   2014.0           1.0         NaN
# 2     0.936   2014.0           0.0  806.179654
# 3     0.954   2014.0           0.0  844.788274
# 4     0.833   2014.0           0.0  861.327751
#
# [5 rows x 67 columns]

# %%
data_2015.head()
# Out:
#   contractid  planid     fips  year  n_nonmiss  avg_enrollment  sd_enrollment  \
# 0      H0022     1.0  39023.0  2015          2           562.0      50.911688
# 1      H0022     1.0  39035.0  2015          2          2783.5      37.476659
# 2      H0022     1.0  39051.0  2015          2           107.5       6.363961
# 3      H0022     1.0  39055.0  2015          2            47.0       1.414214
# 4      H0022     1.0  39057.0  2015          2           509.0      26.870058
#
#    min_enrollment  max_enrollment  first_enrollment  ...  costsharing_partd  \
# 0           526.0           598.0             598.0  ...                NaN
# 1          2757.0          2810.0            2810.0  ...                NaN
# 2           103.0           112.0             112.0  ...                NaN
# 3            46.0            48.0              48.0  ...                NaN
# 4           490.0           528.0             528.0  ...                NaN
#
#   riskscore_partd parta_enroll   parta_reimb partb_enroll   partb_reimb  \
# 0             NaN      14903.0  6.324002e+07      13060.0  6.078756e+07
# 1             NaN     137351.0  6.263799e+08     117519.0  5.379688e+08
# 2             NaN       5838.0  2.429418e+07       5369.0  2.504999e+07
# 3             NaN      10218.0  3.481297e+07       8838.0  3.865505e+07
# 4             NaN      12221.0  4.634145e+07      10641.0  5.035143e+07
#
#   mean_risk year_ffs basic_premium bid
# 0     1.062   2015.0           NaN NaN
# 1     1.061   2015.0           NaN NaN
# 2     0.968   2015.0           NaN NaN
# 3     0.962   2015.0           NaN NaN
# 4     0.991   2015.0           NaN NaN
#
# [5 rows x 67 columns]

# %%
data_2016.head()
# Out:
#   contractid  planid     fips  year  n_nonmiss  avg_enrollment  sd_enrollment  \
# 0      H0022     1.0  39023.0  2016          2           487.0       1.414214
# 1      H0022     1.0  39035.0  2016          2          2613.5      34.648232
# 2      H0022     1.0  39051.0  2016          2            94.0       0.000000
# 3      H0022     1.0  39055.0  2016          2            47.5       3.535534
# 4      H0022     1.0  39057.0  2016          2           454.5       9.192388
#
#    min_enrollment  max_enrollment  first_enrollment  ...  costsharing_partd  \
# 0           486.0           488.0             488.0  ...                NaN
# 1          2589.0          2638.0            2589.0  ...                NaN
# 2            94.0            94.0              94.0  ...                NaN
# 3            45.0            50.0              45.0  ...                NaN
# 4           448.0           461.0             448.0  ...                NaN
#
#   riskscore_partd parta_enroll  parta_reimb partb_enroll  partb_reimb  \
# 0             NaN      15874.0   66831138.0      13982.0   66272395.0
# 1             NaN     147536.0  661508432.0     127434.0  596806473.0
# 2             NaN       6472.0   24293264.0       5959.0   27763543.0
# 3             NaN      11099.0   37027595.0       9681.0   43114519.0
# 4             NaN      13617.0   53342389.0      11950.0   57090671.0
#
#   mean_risk year_ffs basic_premium bid
# 0       NaN   2016.0           NaN NaN
# 1       NaN   2016.0           NaN NaN
# 2       NaN   2016.0           NaN NaN
# 3       NaN   2016.0           NaN NaN
# 4       NaN   2016.0           NaN NaN
#
# [5 rows x 67 columns]

# %%
data_2017.head()
# Out:
#   contractid  planid     fips  year  n_nonmiss  avg_enrollment  sd_enrollment  \
# 0      H0022     1.0  39023.0  2017          2           563.0      12.727922
# 1      H0022     1.0  39035.0  2017          2          3385.0      90.509668
# 2      H0022     1.0  39051.0  2017          2           112.0       7.071068
# 3      H0022     1.0  39055.0  2017          2            60.0       2.828427
# 4      H0022     1.0  39057.0  2017          2           512.5      17.677670
#
#    min_enrollment  max_enrollment  first_enrollment  ...  costsharing_partd  \
# 0           554.0           572.0             554.0  ...                NaN
# 1          3321.0          3449.0            3321.0  ...                NaN
# 2           107.0           117.0             107.0  ...                NaN
# 3            58.0            62.0              58.0  ...                NaN
# 4           500.0           525.0             500.0  ...                NaN
#
#   riskscore_partd parta_enroll  parta_reimb partb_enroll  partb_reimb  \
# 0             NaN      15790.0   67835067.0      13818.0   69718421.0
# 1             NaN     144582.0  647528560.0     123712.0  603686791.0
# 2             NaN       6516.0   23773500.0       5954.0   27368118.0
# 3             NaN      11143.0   39039677.0       9639.0   44900701.0
# 4             NaN      13750.0   54110968.0      11992.0   62131131.0
#
#   mean_risk year_ffs basic_premium bid
# 0    420.46   2017.0           NaN NaN
# 1    406.65   2017.0           NaN NaN
# 2    383.05   2017.0           NaN NaN
# 3    388.19   2017.0           NaN NaN
# 4    431.75   2017.0           NaN NaN
#
# [5 rows x 67 columns]

# %%
data_2018.head()
# Out:
#   contractid  planid     fips  year  n_nonmiss  avg_enrollment  sd_enrollment  \
# 0      H0022     1.0  39023.0  2018          2           571.0      18.384776
# 1      H0022     1.0  39035.0  2018          2          3648.5      74.246212
# 2      H0022     1.0  39051.0  2018          2           107.0       0.000000
# 3      H0022     1.0  39055.0  2018          2            80.0       0.000000
# 4      H0022     1.0  39057.0  2018          2           543.5       6.363961
#
#    min_enrollment  max_enrollment  first_enrollment  ...  costsharing_partd  \
# 0           558.0           584.0             558.0  ...                NaN
# 1          3596.0          3701.0            3596.0  ...                NaN
# 2           107.0           107.0             107.0  ...                NaN
# 3            80.0            80.0              80.0  ...                NaN
# 4           539.0           548.0             539.0  ...                NaN
#
#   riskscore_partd parta_enroll  parta_reimb partb_enroll  partb_reimb  \
# 0             NaN      15753.0   68334261.0      13689.0   72342588.0
# 1             NaN     140616.0  629902401.0     119042.0  617228042.0
# 2             NaN       6379.0   22799811.0       5776.0   28204758.0
# 3             NaN      11294.0   37225211.0       9735.0   47821487.0
# 4             NaN      13834.0   53963556.0      12036.0   62404079.0
#
#   mean_risk year_ffs basic_premium bid
# 0    440.39   2018.0           NaN NaN
# 1    432.08   2018.0           NaN NaN
# 2    406.92   2018.0           NaN NaN
# 3    409.36   2018.0           NaN NaN
# 4    432.07   2018.0           NaN NaN
#
# [5 rows x 67 columns]

# %%
data_2019.head()
# Out:
#   contractid  planid     fips  year  n_nonmiss  avg_enrollment  sd_enrollment  \
# 0      H0022     1.0  39023.0  2019          2           646.0       9.899495
# 1      H0022     1.0  39035.0  2019          2          3744.5       2.121320
# 2      H0022     1.0  39051.0  2019          2           136.5       2.121320
# 3      H0022     1.0  39055.0  2019          2            86.5       0.707107
# 4      H0022     1.0  39057.0  2019          2           630.0       8.485281
#
#    min_enrollment  max_enrollment  first_enrollment  ...  costsharing_partd  \
# 0           639.0           653.0             639.0  ...                NaN
# 1          3743.0          3746.0            3743.0  ...                NaN
# 2           135.0           138.0             135.0  ...                NaN
# 3            86.0            87.0              86.0  ...                NaN
# 4           624.0           636.0             624.0  ...                NaN
#
#   riskscore_partd parta_enroll  parta_reimb partb_enroll  partb_reimb  \
# 0             NaN      11913.0   54535286.0      10572.0   48836995.0
# 1             NaN     115765.0  546898706.0     100343.0  447436608.0
# 2             NaN       4985.0   19660430.0       4646.0   20540343.0
# 3             NaN       9311.0   32717173.0       8088.0   34586867.0
# 4             NaN      10298.0   43133634.0       9075.0   41611278.0
#
#   mean_risk year_ffs basic_premium bid
# 0     1.099   2019.0           NaN NaN
# 1     1.083   2019.0           NaN NaN
# 2     0.969   2019.0           NaN NaN
# 3     0.948   2019.0           NaN NaN
# 4     0.992   2019.0           NaN NaN
#
# [5 rows x 67 columns]

# %%
data_2014["year"] = 2014
data_2015["year"] = 2015
data_2016["year"] = 2016
data_2017["year"] = 2017
data_2018["year"] = 2018
data_2019["year"] = 2019

# %%
data = pd.concat([data_2014, data_2015, data_2016, data_2017, data_2018, data_2019], ignore_index=True)

# %%
data.columns
# Out:
# Index(['contractid', 'planid', 'fips', 'year', 'n_nonmiss', 'avg_enrollment',
#        'sd_enrollment', 'min_enrollment', 'max_enrollment', 'first_enrollment',
#        'last_enrollment', 'state', 'county', 'org_type', 'plan_type', 'partd',
#        'snp', 'eghp', 'org_name', 'org_marketing_name', 'plan_name',
#        'parent_org', 'contract_date', 'state_long', 'county_long', 'year_pen',
#        'n_elig', 'n_enrol', 'avg_eligibles', 'sd_eligibles', 'min_eligibles',
#        'max_eligibles', 'first_eligibles', 'last_eligibles', 'avg_enrolled',
#        'sd_enrolled', 'min_enrolled', 'max_enrolled', 'first_enrolled',
#        'last_enrolled', 'ssa', 'state_name', 'state_land', 'premium',
#        'premium_partc', 'premium_partd_basic', 'premium_partd_supp',
#        'premium_partd_total', 'partd_deductible', 'year_land',
#        'riskscore_partc', 'payment_partc', 'rebate_partc', 'year_reb',
#        'payment_partd', 'directsubsidy_partd', 'reinsurance_partd',
#        'costsharing_partd', 'riskscore_partd', 'parta_enroll', 'parta_reimb',
#        'partb_enroll', 'partb_reimb', 'mean_risk', 'year_ffs', 'basic_premium',
#        'bid'],
#       dtype='object')

# %% [markdown]
# ## Question 1

# %%
question_1 = data[
    (data["snp"] != "Yes") &
    ~((data["planid"] >= 800) & (data["planid"] < 900)) & 
    ~ (data["payment_partc"].isna())].copy()
question_1.head(10)
# Out:
#    contractid  planid     fips  year  n_nonmiss  avg_enrollment  \
# 2       H0028     2.0  19153.0  2014          2           347.0
# 3       H0028     3.0  19155.0  2014          2           173.0
# 4       H0028     4.0  15003.0  2014          2          1019.5
# 5       H0028     4.0  15007.0  2014          2           177.0
# 6       H0028     4.0  15009.0  2014          2           238.5
# 7       H0028     5.0  15003.0  2014          2           234.5
# 8       H0028     5.0  15007.0  2014          2            30.0
# 9       H0028     5.0  15009.0  2014          2            87.5
# 10      H0084     1.0  17001.0  2014          2            24.0
# 11      H0084     1.0  17005.0  2014          2            14.0
#
#     sd_enrollment  min_enrollment  max_enrollment  first_enrollment  ...  \
# 2        1.414214           346.0           348.0             346.0  ...
# 3       11.313708           165.0           181.0             165.0  ...
# 4       20.506097          1005.0          1034.0            1034.0  ...
# 5       25.455844           159.0           195.0             159.0  ...
# 6       23.334524           222.0           255.0             222.0  ...
# 7       20.506097           220.0           249.0             220.0  ...
# 8        8.485281            24.0            36.0              24.0  ...
# 9       10.606602            80.0            95.0              80.0  ...
# 10       1.414214            23.0            25.0              23.0  ...
# 11       0.000000            14.0            14.0              14.0  ...
#
#     costsharing_partd riskscore_partd parta_enroll  parta_reimb partb_enroll  \
# 2               37.09           0.910      46091.0  138761798.0      41137.0
# 3               37.96           0.983      10934.0   38584530.0      10013.0
# 4               14.16           0.829      76625.0  198161786.0      59102.0
# 5               14.16           0.829       6730.0   17199086.0       5473.0
# 6               14.16           0.829      10725.0   27670770.0       8246.0
# 7               25.02           0.748      76625.0  198161786.0      59102.0
# 8               25.02           0.748       6730.0   17199086.0       5473.0
# 9               25.02           0.748      10725.0   27670770.0       8246.0
# 10              17.48           0.816      10776.0   43159764.0      10103.0
# 11              17.48           0.816       2343.0    9365608.0       2226.0
#
#     partb_reimb mean_risk year_ffs basic_premium          bid
# 2   146914297.0     0.936   2014.0           0.0   806.179654
# 3    40401051.0     0.954   2014.0           0.0   844.788274
# 4   182990122.0     0.833   2014.0           0.0   861.327751
# 5    16635989.0     0.795   2014.0           0.0   861.327751
# 6    25732595.0     0.811   2014.0           0.0   861.327751
# 7   182990122.0     0.833   2014.0           0.0  1105.498534
# 8    16635989.0     0.795   2014.0           0.0  1105.498534
# 9    25732595.0     0.811   2014.0           0.0  1105.498534
# 10   45642370.0     1.011   2014.0           0.0   818.390663
# 11   10129565.0     1.023   2014.0           0.0   818.390663
#
# [10 rows x 67 columns]

# %%
plan_counts = (
    question_1
    .groupby(["year", "fips"])["planid"]
    .nunique()
    .reset_index(name="num_unique_plans")
)
plan_counts.head()
# Out:
#    year    fips  num_unique_plans
# 0  2014  1001.0                 9
# 1  2014  1003.0                19
# 2  2014  1005.0                 8
# 3  2014  1007.0                 6
# 4  2014  1009.0                 9

# %%
plt.figure()

plan_counts.boxplot(
    column="num_unique_plans",
    by="year"
)

plt.title("Plan Counts by County")
plt.suptitle("")
plt.xlabel("Year")
plt.ylabel("Number of Plans in County")

plt.show()

# %% [markdown]
# #### Interpretation: The plot shows the number of Medicare Advantage plans available per county increases from 2014 to 2019. Thus, the number of plans seems sufficient enough to provide meaningful beneficiary choice.

# %% [markdown]
# ## Question 2

# %%
question_2 = data[
    (data["snp"] != "Yes") &
    ~((data["planid"] >= 800) & (data["planid"] < 900)) &
    ~(data["payment_partc"].isna())
].copy()

# %%
# 2014
bid_2014 = data_2014['bid'].dropna()
plt.figure()
plt.hist(bid_2014, bins=40)
plt.title("Distribution of Plan Bids – 2014")
plt.xlabel("Bid")
plt.ylabel("Frequency")
plt.show()

# 2018
bid_2018 = data_2018['bid'].dropna()
plt.figure()
plt.hist(bid_2018, bins=40)
plt.title("Distribution of Plan Bids – 2018")
plt.xlabel("Bid")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# #### Interpretation: From 2014 to 2018, the distribution of plan bids appeared to shift slightly downward and became more concentrated. In 2014, there is more variation in bids and more high-bid outliers. By 2018, however, bids are more tightly clustered around the median value.

# %% [markdown]
# ## Question 3

# %%
# pick the enrollment measure
enroll_col = 'avg_enrollment'

# total MA enrollment per county-year market
data['total_ma_enroll'] = (
    data.groupby(['ssa', 'year'])[enroll_col]
        .transform('sum')
)

# market share + HHI pieces
data['share'] = data[enroll_col] / data['total_ma_enroll']
data['share_sq'] = data['share'] ** 2

# county-year HHI
hhi_county = (
    data.groupby(['ssa', 'year'])['share_sq']
        .sum()
        .reset_index(name='hhi')
)

# average HHI by year
avg_hhi = (
    hhi_county.groupby('year')['hhi']
        .mean()
        .reset_index()
)

avg_hhi
# Out:
#    year       hhi
# 0  2014  0.353853
# 1  2015  0.341526
# 2  2016  0.341877
# 3  2017  0.341011
# 4  2018  0.325329
# 5  2019  0.294956

# %%
plt.figure()
plt.plot(avg_hhi['year'], avg_hhi['hhi'], marker='o')
plt.xlabel('Year')
plt.ylabel('Average HHI')
plt.title('Average Medicare Advantage HHI, 2014–2019')
plt.show()

# %% [markdown]
# #### Interpretation: The average HHI for MA markets declined from 2014 to 2019. After a modest decrease from 2014 to 2015, market concentration remained relatively stable through 2017, before falling sharply by 2019. This would suggest Medicare Advantage markets likely became more competitive over time.

# %% [markdown]
# ## Question 4

# %%
ma_share_county = (
    data[['ssa', 'year', 'avg_enrolled', 'avg_eligibles']]
        .drop_duplicates()
        .assign(ma_share=lambda x: x['avg_enrolled'] / x['avg_eligibles'])
)

# %%
avg_ma_share = (
    ma_share_county.groupby('year')['ma_share']
        .mean()
        .reset_index()
)

# %%
plt.figure()
plt.plot(avg_ma_share['year'], avg_ma_share['ma_share'], marker='o')
plt.xlabel('Year')
plt.ylabel('Average Medicare Advantage Share')
plt.title('Average Medicare Advantage Share, 2014–2019')
plt.show()

# %% [markdown]
# #### Interpretation: The average share of Medicare beneficiaries enrolled in Medicare Advantage have steadily increased from 2014 to 2019, which indicates that Medicare Advantage became more popular over time.

# %% [markdown]
# ## Question 5

# %%
data_2018 = data[data['year'] == 2018].copy()

# %%
hhi_2018 = hhi_county[hhi_county['year'] == 2018].copy()

# %%
hhi_33 = hhi_2018['hhi'].quantile(0.33)
hhi_66 = hhi_2018['hhi'].quantile(0.66)

hhi_33, hhi_66
# Out:
# (np.float64(0.20572216334316112), np.float64(0.3528291524673865))

# %%
hhi_2018['market_type'] = 'middle'

hhi_2018.loc[hhi_2018['hhi'] <= hhi_33, 'market_type'] = 'competitive'
hhi_2018.loc[hhi_2018['hhi'] >= hhi_66, 'market_type'] = 'uncompetitive'

# %%
data_2018 = data_2018.merge(
    hhi_2018[['ssa', 'market_type']],
    on='ssa',
    how='left'
)

# %%
data_2018 = data_2018[data_2018['market_type'].isin(['competitive', 'uncompetitive'])]

# %%
avg_bid = (
    data_2018.groupby('market_type')['bid']
        .mean()
        .reset_index()
)

avg_bid
# Out:
#      market_type         bid
# 0    competitive  766.200797
# 1  uncompetitive  772.702247

# %% [markdown]
# ## Question 6

# %%
data_2018 = data_2018.copy()

# %%
data_2018['ffs_cost'] = (
    (data_2018['parta_reimb'] + data_2018['partb_reimb']) /
    (data_2018['parta_enroll'] + data_2018['partb_enroll'])
)

# %%
ffs_2018 = (
    data_2018[['ssa', 'ffs_cost']]
        .drop_duplicates()
)

# %%
ffs_2018['ffs_quartile'] = pd.qcut(
    ffs_2018['ffs_cost'],
    4,
    labels=[1, 2, 3, 4]
)

# %%
for q in [1, 2, 3, 4]:
    ffs_2018[f'ffs_q{q}'] = (ffs_2018['ffs_quartile'] == q).astype(int)

# %%
data_2018 = data_2018.merge(
    ffs_2018[['ssa', 'ffs_quartile', 'ffs_q1', 'ffs_q2', 'ffs_q3', 'ffs_q4']],
    on='ssa',
    how='left'
)

# %%
avg_bid_quartile = (
    data_2018
        .groupby(['ffs_quartile', 'market_type'])['bid']
        .mean()
        .reset_index()
        .pivot(index='ffs_quartile', columns='market_type', values='bid')
        .reset_index()
)

avg_bid_quartile
# Out:
# /tmp/ipykernel_3469501/2096705428.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   .groupby(['ffs_quartile', 'market_type'])['bid']
# market_type ffs_quartile  competitive  uncompetitive
# 0                      1   786.035289     790.893468
# 1                      2   777.047844     770.667362
# 2                      3   759.183521     760.905748
# 3                      4   748.543613     771.623887

# %% [markdown]
# ## Question 7

# %%
df = data[data['year'] == 2018].copy()

# get 2018 HHI (county-year)
hhi_2018 = hhi_county[hhi_county['year'] == 2018][['ssa', 'hhi']].copy()

# merge HHI into df
df = df.merge(hhi_2018, on='ssa', how='left')

# %%
hhi_33 = hhi_2018['hhi'].quantile(0.33)
hhi_66 = hhi_2018['hhi'].quantile(0.66)

df['market_type'] = 'middle'
df.loc[df['hhi'] <= hhi_33, 'market_type'] = 'competitive'
df.loc[df['hhi'] >= hhi_66, 'market_type'] = 'uncompetitive'

# %%
df = df[df['market_type'].isin(['competitive', 'uncompetitive'])].copy()

# %%
df['T'] = (df['market_type'] == 'uncompetitive').astype(int)  # High HHI treated
df['Y'] = df['bid']

# %%
df['ffs_cost'] = (
    (df['parta_reimb'] + df['partb_reimb']) /
    (df['parta_enroll'] + df['partb_enroll'])
)

ffs = df[['ssa', 'ffs_cost']].drop_duplicates().copy()
ffs['ffs_quartile'] = pd.qcut(ffs['ffs_cost'], 4, labels=[1,2,3,4])
ffs = pd.get_dummies(ffs, columns=['ffs_quartile'], prefix='q', dtype=int)

df = df.merge(ffs[['ssa','q_1','q_2','q_3','q_4']], on='ssa', how='left')
df_bal = df.dropna(subset=['Y','T','q_1','q_2','q_3','q_4']).copy()

# %%
quart = df_bal[['q_1','q_2','q_3','q_4']].idxmax(axis=1)

m = df_bal.groupby([quart, 'T'])['Y'].mean().unstack()
m['diff_q'] = m[1] - m[0]

w = df_bal[df_bal['T'] == 1].groupby(quart).size()

att = (m['diff_q'] * w).sum() / w.sum()
att
# Out:
# np.float64(4.94349390979783)

# %%
results_q7 = pd.DataFrame({
    "Estimator": ["INV", "MAH", "IPW", "OLS"],
    "ATE (High HHI)": [att, att, att, att]
})
results_q7
# Out:
#   Estimator  ATE (High HHI)
# 0       INV        4.943494
# 1       MAH        4.943494
# 2       IPW        4.943494
# 3       OLS        4.943494
