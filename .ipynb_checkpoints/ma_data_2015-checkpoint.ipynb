# %%
## Packages

import pandas as pd
import numpy as np
from pathlib import Path
import os
from data_build.functions import (
    load_month,
    load_month_sa,
    load_month_pen,
    mapd_clean_merge
)

# Settings
monthlist = [f"{m:02d}" for m in range(1, 3)]
y = 2015
